# %%
import pandas as pd

# %%
path = '../../../archive (2)/steam-games.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#         app_id                                              title  \
# 0          730                                   Counter-Strike 2
# 1          570                                             Dota 2
# 2      2215430                   Ghost of Tsushima DIRECTOR'S CUT
# 3      1245620                                         ELDEN RING
# 4      1085660                                          Destiny 2
# ...        ...                                                ...
# 42492   477910                               Wanderer of Teandria
# 42493  1501390                                          KING PONG
# 42494  2683250                              Falnarion Tactics III
# 42495  1508840  Great Exploration VR: New Colony beyond Viking...
# 42496  1191080                                           SANCTION
#
#        release_date                                             genres  \
# 0      21 Aug, 2012                               Action, Free to Play
# ...

# %%
import plotly.express  as px

# %%
px.scatter(
    data_frame=df,
    x='discounted_price',
    y='recent_review_%',
)
# Out:
# <div>                            <div id="560b5ad3-34f2-4684-b7da-4789ed7174fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("560b5ad3-34f2-4684-b7da-4789ed7174fb")) {                    Plotly.newPlot(                        "560b5ad3-34f2-4684-b7da-4789ed7174fb",                        [{"hovertemplate":"discounted_price=%{x}\u003cbr\u003erecent_review_%=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["Free","Free","\u20b93,999.00","\u20b93,599.00","Free","\u20b91,499.00","\u20b92,999.00","Free","Free","\u20b92,249.00","\u20b92,499.00","\u20b91,300.00","\u20b91,197.00","\u20b91,799.00","\u20b9952.00","Free","\u20b9230.00","\u20b92,499
# ...
